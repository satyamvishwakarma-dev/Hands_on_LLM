# %% [markdown]
# # Chapter 1: Introduction to Large Language Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=False,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# ...

# %%
import os

# 1. Check current directory on Colab
print("Files in current Colab directory:")
print(os.listdir('.'))

# 2. Check Hugging Face cache directory
hf_cache = os.path.expanduser('~/.cache/huggingface/hub')
if os.path.exists(hf_cache):
    print("\nDownloaded Hugging Face Models on Colab:")
    print(os.listdir(hf_cache))
# Out:
# Files in current Colab directory:
# ['.config', 'sample_data']
#
# Downloaded Hugging Face Models on Colab:
# ['CACHEDIR.TAG', '.locks', 'models--microsoft--Phi-3-mini-4k-instruct']
